# %% [markdown]
# # **INPUT MODULE FOR PREDICTIONS**

# %%
import numpy as np
from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.models import load_model
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input


uploaded =  files.upload()
model = load_model('best.h5')
for fn in uploaded.keys():
    #image prediction
    path = '/content/' + fn
    img = image.load_img(path, target_size = (150, 150))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis = 0)
    img_data = preprocess_input(x)
    images = np.vstack([x])
    classes = model.predict(images, batch_size = 10)
    plt.imshow(img)
    plt.show()
    classes = model.predict(img_data)
    print(classes)
    if (classes) >= 1.0:
     print('PNEUMONIA')
    else:
     print('NORMAL')
# Out:
#      <input type="file" id="files-36cb8abe-b1fa-438e-b007-207bb32bf264" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36cb8abe-b1fa-438e-b007-207bb32bf264">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NORMAL2-IM-0381-0001.jpeg to NORMAL2-IM-0381-0001.jpeg
# Saving NORMAL2-IM-1197-0001.jpeg to NORMAL2-IM-1197-0001.jpeg
# Saving NORMAL2-IM-1202-0001.jpeg to NORMAL2-IM-1202-0001.jpeg
# Saving NORMAL2-IM-1203-0001.jpeg to NORMAL2-IM-1203-0001.jpeg
# [[0.]]
# NORMAL
# [[0.]]
# NORMAL
# [[0.]]
# NORMAL
# [[0.]]
# NORMAL
